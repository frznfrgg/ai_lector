# %%
import os
import warnings

import rec_analyzer

warnings.filterwarnings("ignore")

# %%
PYANNOTE_AUTH_TOKEN = os.environ.get("PYANNOTE_API_KEY")
GIGACHAT_API_KEY = os.environ.get("GIGACHAT_API_KEY")
recording_path = "audio/rec.mp3"

# %%
analyzer = rec_analyzer.LectureHelper(
    recording_path, GIGACHAT_API_KEY, PYANNOTE_AUTH_TOKEN
)

# %%
analyzer.lecture_text
# Out:
# Device set to use cuda:0
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# You have passed language=russian, but also have set `forced_decoder_ids` to [[1, None], [2, 50360]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of language=russian.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# ' Так, друзья, ну все, я больше подписываюсь. пока ничего не буду, сейчас будет лекция. Значит, смотрите, ну я из года в год читаю, конечно, эти лекции, в принципе, есть их записи, вот, но я с удовольствием прочитаю снова, может быть, что-нибудь новое случится на этот раз. На самом деле мне, конечно, хочется читать гораздо быстрее, чем обычно я это делаю, то есть начитывать такой более объемный, более мощный материал, но традиция сложилась такая, что поскольку к магистратуру идут люди самого разного, начального уровня подготовки, приходится очень многое напоминать. Ну и, наверное, сейчас мы тоже что-то такое проделаем, но все-таки я хочу с места в карьер пойти на какую-то достаточно продвинутую тематику. Курс посвящен комбинаторике. Ну... Методы, которые хочется рассказывать в рамках этого курса, они достаточно продвинутые. То есть я ни в коем случае не хочу читать такой вводный курс о том, что такое C из НПК, там, не дай бог. Я предполагаю, что слушатели знают, что такое C из НПК. Я предполагаю, что слушатели, конечно, знают, что такое граф. Поэтому с места в карьер я буду рассказывать какие-то вещи типа графы, гиперграфы. Но все это будет собрано в рамках методов. То есть я буду рассказывать про методы, которые работают в современной комбинаторике. В первую очередь это будет вероятностный метод, ну а попозже мы придем еще к алгебраическим технологиям, которые тоже позволяют решать сложные комбинаторные задачи. Ну и все будет построено вокруг некоторого количества задач, такой вот, если угодно, экстремальной комбинаторики. Экстремальной не в смысле сложности ее, а в смысле, что обычно изучаются задачи на экстремумы, то есть найти максимальное количество чего-нибудь или там самый какой-то такой-то случай. Вот, ну сейчас будут конкретные примеры, давайте действительно начнем с вероятностного метода, его в каком-то смысле будем развивать очень последовательно, то есть начнем с каких-то самых простых моментов, а потом перейдем в конечном счете к очень продвинутым неравенствам плотной концентрации мер и еще чего-то. Ну то есть кого-то может кокнуть, но вы магистранты, все-таки, пожалуйста, держитесь. Соответственно, если вы чувствуете, что вас кокает сейчас, вы что-то не понимаете, вы, конечно, обязательно спрашивайте. Тут я так понимаю, что можно и голосом говорить, да, ведь в Zoom? Народу там всего 4 человека, кажись, или 3? Или я не всех вижу? То есть народу совсем немного, мы можем очень так келейно пообщаться. Зато всем все будет понятно, если вы не будете стесняться задавать вопросы. Сейчас я еще мел найду. Так, ну давайте я сразу прямо скажу, что есть такой замечательный объект, в комбинаторике, в теории графов, который обобщает понятие графа, и называется он гиперграф. Это будет удобный объект для самых разных задач, и вокруг него как раз будут формулироваться интересные такие экстремальные вопросы. Ну и вероятностный метод на них тоже можно будет очень хорошо... Иллюстрировать. Что еще раз. Мы начинаем изучать вероятностный метод в комбинаторике с постановок некоторых конкретных задач из простейших вероятностных метров. Но для этого, в частности, мне нужно напомнить, что есть такой объект, который называется гиперграф. относных мест. Но для этого Ну, подобно графу, его можно обозначить, естественно, какой-нибудь буквой, у него есть, так же точно, как и у графа, Некоторое множество вершин, конечное множество, как правило, конечное, множество объектов любых, совершенно любой природы. И есть множество ребер. Ну, вроде как, вообще звучит никакой разницы. Да, граф у него есть вершины, есть ребра. И у гиперграфа тоже есть вершины и ребра. Но гиперность, так сказать, обобщения состоит в том, что ребра... В данном случае это не обязательно пара элементов, а это какие-то подмножества. множество вершин. Не обязательно пары вершин, но, может быть, тройки вершин, например, или какие-то наборы большей мощности. То есть, E Можно вот так написать. Это подмножество в множестве всех подмножеств. Так, 2 в степени v – это естественное обозн ...

# %%
analyzer.abstract_text
# Out:
# INFO:httpx:HTTP Request: POST https://ngw.devices.sberbank.ru:9443/api/v2/oauth "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://gigachat.devices.sberbank.ru/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://gigachat.devices.sberbank.ru/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://gigachat.devices.sberbank.ru/api/v1/chat/completions "HTTP/1.1 200 OK"
# '### Конспект лекции\n\n#### Введение\nЛектор начинает занятие с заявления о своем желании читать лекции быстрее, однако отмечает, что вынужден напоминать много материала из-за различного уровня подготовки студентов. Лектор планирует перейти к продвинутой тематике, касающейся комбинаторики. Основное внимание уделяется методам, используемым в современной комбинаторике, включая вероятностный метод и алгебраические технологии.\n\n#### Определения и терминология\nЛектор напоминает, что слушатели должны знать основы теории графов и гиперграфов. Гиперграф - это обобщение понятия графа, где ребра могут включать любые подмножества вершин, а не только пары. Хроматическое число гиперграфа определяется как минимальное количество цветов, необходимых для раскраски вершин таким образом, чтобы каждое ребро было неодноцветным.\n\n#### Пример теоремы\nЛектор приводит пример теоремы, доказанной в 1961 году Эрдошем и Хайналь, которая утверждает, что если количество ребер в N-однородном гиперграфе меньше чем 2^n-1, то его хроматическое число не превышает 2. Это означает, что такой гиперграф можно раскрасить в два цвета.\n\n#### Доказательство теоремы\nДоказательство строится на основе вероятностного подхода. Слушателей просят представить случайную раскраску вершин гиперграфа, где каждая вершина окрашивается независимо с равной вероятностью. Для любого конкретного ребра вероятность того, что оно останется одноцветным, рассчитывается как 2^(1-n). Затем рассматривается объединение всех таких событий, что дает верхнюю оценку для вероятности того, что хотя бы одно ребро останется одноцветным. Используя принцип Дирихле, лектор показывает, что для полного n-однородного гиперграфа невозможно выполнить такую раскраску.\n\n#### Обсуждение оценок\nЛектор обсуждает верхнюю и нижнюю оценки для MATN (минимальное количество ребер, при котором гиперграф не может быть раскрашен в два цвета). Он указывает, что разница между оценками составляет порядка 4^n, что значительно больше, чем 2^n. Однако, используя дополнительные вероятностные методы, можно улучшить эту оценку.\n\n#### Заключительное замечание\nЛектор завершает лекцию, подчеркивая важность дальнейшего изучения продвинутых методов в комбинаторике и вероятностных технологий, которые помогут сократить разрыв между верхней и нижней оценками.'

# %%
analyzer.questions
# Out:
# '1. Какие основные темы обсуждаются в курсе лекций по комбинаторике?\n2. Каковы основные методы, которые будут рассмотрены в рамках курса?\n3. Что такое гиперграф и как он отличается от графа?\n4. В чем заключается основная идея теоремы, доказанной Эрдошем и Хайналь в 1961 году?'

# %%
print(analyzer.mind_map)
# Out:
# ```json
# {
#     "title": "Комбинаторика и гиперграфы",
#     "nodes": [
#         {
#             "id": "комбинаторика",
#             "label": "Комбинаторика",
#             "nodes": [
#                 {
#                     "id": "методы-современной-комбинаторики",
#                     "label": "Методы современной комбинаторики",
#                     "nodes": []
#                 },
#                 {
#                     "id": "вероятностный-метод",
#                     "label": "Вероятностный метод",
#                     "nodes": []
#                 },
#                 {
#                     "id": "алгебраические-технологии",
#                     "label": "Алгебраические технологии",
#                     "nodes": []
#                 }
#             ]
#         },
#         {
#             "id": "гиперграфы",
#             "label": "Гиперграфы",
#             "nodes": [
#                 {
#                     "id": "обобщение-понятия-графа",
#                     "label": "Обобщение понятия графа",
#                     "nodes": []
#                 },
#                 {
#                     "id": "раскраска-вершин-гиперграфа",
#                     "label": "Раскраска вершин гиперграфа",
#                     "nodes": []
#                 },
#                 {
#                     "id": "хроматическое-число-гиперграфа",
#                     "label": "Хроматическое число гиперграфа",
#                     "nodes": []
#                 }
#             ]
#         }
#     ]
# }
# ```

# %%
analyzer.popular_words
# Out:
# [[('это', 75),
#   ('n', 19),
#   ('просто', 14),
#   ('очень', 13),
#   ('такое', 12),
#   ('множество', 12),
#   ('количество', 11),
#   ('давайте', 10),
#   ('вершины', 10),
#   ('вершин', 10)],
#  [('убрать', 2),
#   ('относных', 1),
#   ('субтитры', 1),
#   ('создавал', 1),
#   ('dimatorzok', 1),
#   ('понятно', 1),
#   ('зуме', 1),
#   ('народ', 1),
#   ('минус', 1),
#   ('изыскать', 1)]]

# %%
analyzer.diagram
# Out:
# {'lecturer': 74.4883652765337,
#  'discussion': 1.345852616875226,
#  'quiet': 24.165782106591077}

# %%
analyzer.speed
# Out:
# {9.19: 3.0349547328412996,
#  10.97: 2.9177635998078633,
#  13.06: 2.800673480673524,
#  13.73: 2.684108873383887,
#  56.39: 2.571223922899092,
#  56.75: 2.464523166871155,
#  57.74: 2.3671555546909238,
#  58.35: 2.2794607978555717,
#  87.11: 2.201654833975977,
#  87.65: 2.134628605638107,
#  92.24: 2.079075781280759,
#  92.4: 2.0343810085686123,
#  102.83: 1.9998054246893884,
#  102.97: 1.9741476324105645,
#  121.24: 1.9566625055990978,
#  121.73: 1.9456000912662934,
#  153.58: 1.9384869735548116,
#  153.69: 1.9343542301781653,
#  161.52: 1.9325709349044349,
#  161.66: 1.9305081725309832,
#  162.87: 1.9261460761806823,
#  165.0: 1.9194533355650854,
#  175.19: 1.9087130439002151,
#  175.4: 1.894454963875449,
#  176.71: 1.8753868366312965,
#  178.37: 1.8511161142381265,
#  178.45: 1.8244238308309761,
#  182.33: 1.7966621461492451,
#  188.44: 1.767657908379701,
#  188.9: 1.7388149732340699,
#  206.51: 1.713189440212717,
#   ' Значит, смотрите, ну я из года в год читаю, конечно, эти лекции, в принципе, есть их записи, вот, но я с удовольствием прочитаю снова, может быть, что-нибудь новое случится на этот раз. На самом деле мне, конечно, хочется читать гораздо быстрее, чем обычно я это делаю, то есть начитывать такой более объемный, более мощный материал, но традиция сложилась такая, что поскольку к магистратуру идут люди самого разного, начального уровня подготовки, приходится очень многое напоминать. Ну и, наверное, сейчас мы тоже что-то такое проделаем, но все-таки я хочу с места в карьер пойти на какую-то достаточно продвинутую тематику. Курс посвящен комбинаторике.',
#   (13.73, 56.39)],
#  ['Silence', '', (56.39, 56.75)],
#  ['Lector', ' Ну...', (56.75, 57.74)],
#  ['Silence', '', (57.74, 58.35)],
#  ['Lector',
#   ' Методы, которые хочется рассказывать в рамках этого курса, они достаточно продвинутые. То есть я ни в коем случае не хочу читать такой вводный курс о том, что такое C из НПК, там, не дай бог. Я предполагаю, что слушатели знают, что такое C из НПК. Я предполагаю, что слушатели, конечно, знают, что такое граф. Поэтому с места в карьер я буду рассказывать какие-то вещи типа графы, гиперграфы. Но все это будет собрано в рамках методов.',
#   (58.35, 87.11)],
#  ['Silence', '', (87.11, 87.65)],
#  ['Lector',
#   ' То есть я буду рассказывать про методы, которые работают в современной комбинаторике.',
#   (87.65, 92.24)],
#  ['Silence', '', (92.24, 92.4)],
#  ['Lector',
#   ' В первую очередь это будет вероятностный метод, ну а попозже мы придем еще к алгебраическим технологиям, которые тоже позволяют решать сложные комбинаторные задачи.',
#   (92.4, 102.83)],
#  ['Silence', '', (102.83, 102.97)],
#  ['Lector',
#   ' Ну и все будет построено вокруг некоторого количества задач, такой вот, если угодно, экстремальной комбинаторики. Экстремальной не в смысле сложности ее, а в смысле, что обычно изучаются задачи на экстремумы, то есть найти максимальное количество чего-нибудь или там самый какой-то такой-то случай.',
#   (102.97, 121.24)],
#  ['Silence', '', (121.24, 121.73)],
#  ['Lector',
#   ' Вот, ну сейчас будут конкретные примеры, давайте действительно начнем с вероятностного метода, его в каком-то смысле будем развивать очень последовательно, то есть начнем с каких-то самых простых моментов, а потом перейдем в конечном счете к очень продвинутым неравенствам плотной концентрации мер и еще чего-то. Ну то есть кого-то может кокнуть, но вы магистранты, все-таки, пожалуйста, держитесь. Соответственно, если вы чувствуете, что вас кокает сейчас, вы что-то не понимаете, вы, конечно, обязательно спрашивайте.',
#   (121.73, 153.58)],
#  ['Silence', '', (153.58, 153.69)],
#  ['Lector',
#   ' Тут я так понимаю, что можно и голосом говорить, да, ведь в Zoom? Народу там всего 4 человека, кажись, или 3?',
#   (153.69, 161.52)],
#  ['Silence', '', (161.52, 161.66)],
#  ['Lector', ' Или я не всех вижу?', (161.66, 162.87)],
#  ['Silence', '', (162.87, 165.0)],
#  ['Lector',
#   ' То есть народу совсем немного, мы можем очень так келейно пообщаться. Зато всем все будет понятно, если вы не будете стесняться задавать вопросы.',
#   (165.0, 175.19)],
#  ['Silence', '', (175.19, 175.4)],
#  ['Lector', ' Сейчас я еще мел найду.', (175.4, 176.71)],
#  ['Silence', '', (176.71, 178.37)],
#  ['Silence', '', (178.37, 178.45)],
#  ['Silence', '', (178.45, 182.33)],
#  ['Lector',
#   ' Так, ну давайте я сразу прямо скажу, что есть такой замечательный объект,',
#   (182.33, 188.44)],
#  ['Silence', '', (188.44, 188.9)],
#  ['Lector',
#   ' в комбинаторике, в теории графов, который обобщает понятие графа, и называется он гиперграф. Это будет удобный объект для самых разных задач, и вокруг него как раз будут формулироваться интересные такие экстремальные вопросы. Ну и вероятностный метод на них тоже можно будет очень хорошо...',
#   (188.9, 206.51)],
#  ['Silence', '', (206.51, 207.51)],
#  ['Lector', ' Иллюстрировать.', (207.51, 208.39)],
#  ['Silence', '', (208.39, 209.38)],
#  ['Lector', ' Что еще раз.', (209.38, 210.16)],
#  ['Silence', '', (210.16, 210.45)],
#  ['Lector', ' Мы начинаем изучать', (210.45, 211.76)],
#  ['Silence', '', (211.76, 212.32)],
#  ['Lector', ' вероятностный метод в комбинаторике', (212.32, 214.46)],
#  ['Silence', '', (214.46, 215.88)],
#  ['Lector',
#   ' с постановок некоторых конкретных задач из простейших вероятностных метров. Но для этого, в частности, мне нужно напомнить, что есть такой объект, который называется гиперграф.',
#   (215.88, 224.59)],
#  ['Audience', ' относных мест. Но для этого', (218.8, 220.28)],
#  ['Silence', '', (220.28, 225.92)],
#  ['Lector',
#   ' Ну, подобно графу, его можно обозначить, естественно, какой-нибудь буквой, у него есть, так же точно, как и у графа,',
#   (225.92, 235.0)],
#  ['Silence', '', (235.0, 235.71)],
#  ['Lector',
#   ' Некоторое множество вершин, конечное множество, как правило, конечное, множество объектов любых, совершенно любой природы.',
#   (235.71, 243.6)],
#  ['Silence', '', (243.6, 244.14)],
#  ['Lector', ' И есть множество ребер.', (244.14, 246.0)],
#  ['Silence', '', (246.0, 247.67)],
#  ['Lector',
#   ' Ну, вроде как, вообще звучит никакой разницы. Да, граф у него есть вершины, есть ребра. И у гиперграфа тоже есть вершины и ребра. Но гиперность, так сказать, обобщения состоит в том, что ребра...',
#   (247.67, 261.31)],
#  ['Silence', '', (261.31, 262.2)],
#  ['Lector',
#   ' В данном случае это не обязательно пара элементов, а это какие-то подмножества.',
#   (262.2, 266.39)],
#  ['Silence', '', (266.39, 266.77)],
#  ['Lector',
#   ' множество вершин. Не обязательно пары вершин, но, может быть, тройки вершин, например, или какие-то наборы большей мощности. То есть, E',
#   (266.77, 275.68)],
#  ['Silence', '', (275.68, 276.33)],
#  ['Lector', ' Можно вот так написать.', (276.33, 277.71)],
#  ['Silence', '', (277.71, 278.79)],
#  ['Lector',
#   ' Это подмножество в множестве всех подмножеств.',
#   (278.79, 282.23)],
#  ['Silence', '', (282.23, 284.04)],
#  ['Lector',
#   ' Так, 2 в степени v – это естественное обозначение для множества всех подмножеств. Если мы берем там подмножество, это значит такая совокупность множеств,',
#   (284.04, 291.8)],
#  ['Silence', '', (291.8, 292.56)],
#  ['Lector', ' Вершин. Совокупность множеств вершин.', (292.56, 294.74)],
#  ['Silence', '', (294.74, 295.98)],
#  ['Lector',
#   ' Так, если вопросов нет, я, конечно, могу разогнаться, я с любой скоростью могу рассказывать. Не знаю, опять же, какая подготовка начальная у тех, кто сейчас меня слушает.',
#   (295.98, 307.07)],
#  ['Silence', '', (307.07, 307.83)],
#  ['Lector', ' Гиперграф называется N-однородным.', (307.83, 310.85)],
#  ['Silence', '', (310.85, 312.24)],
#  ['Lector',
#   ' Мы будем изучать только однородные гиперграфы.',
#   (312.24, 314.85)],
#  ['Silence', '', (314.85, 315.48)],
#  ['Lector', ' называется N однородным', (315.48, 317.37)],
#  ['Silence', '', (317.37, 320.28)],
#  ['Lector', ' если любое его ребро', (320.28, 322.07)],
#  ['Silence', '', (322.07, 324.57)],
#  ['Lector', ' Состоит из n вершин, имеет мощность n.', (324.57, 327.41)],
#  ['Silence', '', (327.41, 329.55)],
#  ['Lector',
#   ' Ну, то есть два однородных гиперграфа – это обычный граф.',
#   (329.55, 332.03)],
#  ['Silence', '', (332.03, 332.86)],
#  ['Lector', ' Ну, мы будем считать, что n...', (332.86, 334.8)],
#  ['Silence', '', (334.8, 336.2)],
#  ['Lector',
#   ' больше либо равняются двойке, потому что, как правило, по крайней мере, поначалу нас будут интересовать раскраски.',
#   (336.2, 342.12)],
#  ['Silence', '', (342.12, 343.37)],
#  ['Lector',
#   ' Вершин гиперграфа в духе того, как красят вершину графов. Вот такая важная.',
#   (343.37, 349.14)],
#  ['Silence', '', (349.14, 349.51)],
#  ['Lector', ' Тематика, связанная с раскраской.', (349.51, 351.44)],
#  ['Silence', '', (351.44, 355.0)],
#  ['Lector', ' Так, ну...', (355.0, 356.11)],
#  ['Silence', '', (356.11, 356.84)],
#  ['Lector',
#   ' Давайте я все-таки задам вопрос к слушателям.',
#   (356.84, 358.89)],
#  ['Silence', '', (358.89, 360.41)],
#  ['Lector',
#   ' Не знаю, как-нибудь скажите мне, пожалуйста, вот у графа что такое хроматическое число, вы знаете?',
#   (360.41, 366.94)],
#  ['Silence', '', (366.94, 368.01)],
#  ['Lector',
#   ' Так вот, сидящий в аудитории человек знает...',
#   (368.01, 370.34)],
#  ['Silence', '', (370.34, 371.52)],
#  ['Lector', ' а сидящие в зуме', (371.52, 372.78)],
#  ['Silence', '', (372.78, 373.29)],
#  ['Audience', ' Да.', (373.29, 373.88)],
#  ['Silence', '', (373.88, 374.64)],
#  ['Audience', ' Тоже знаем.', (374.64, 375.3)],
#  ['Silence', '', (375.3, 375.89)],
#  ['Lector', ' Один знает, а еще двое.', (375.89, 377.54)],
#  ['Silence', '', (377.54, 378.22)],
#  ['Audience', ' Да, да.', (378.22, 378.76)],
#  ['Silence', '', (378.76, 380.73)],
#  ['Audience', ' Позже.', (380.73, 381.09)],
#  ['Silence', '', (381.09, 381.57)],
#  ['Lector', ' вышли.', (381.57, 381.83)],
#  ['Silence', '', (381.83, 382.3)],
#  ['Lector',
#   ' Так, ну прекрасно, значит, хроматическое число графа вы знаете, это минимальное число цветов.',
#   (382.3, 386.92)],
#  ['Silence', '', (386.92, 387.26)],
#  ['Lector', ' такой раскраски вершин что каждый ребром', (387.26, 390.2)],
#  ['Silence', '', (390.2, 391.67)],
#  ['Lector', ' имеет концы разного цвета, да?', (391.67, 393.49)],
#  ['Silence', '', (393.49, 394.6)],
#  ['Lector',
#   ' Если у нас теперь есть гиперграф, ну, например, n однородный и n больше двойки строго, то',
#   (394.6, 401.23)],
#  ['Silence', '', (401.23, 402.5)],
#  ['Lector', ' Сейчас.', (402.5, 402.87)],
#  ['Silence', '', (402.87, 404.66)],
#  ['Lector',
#   ' то понятие хроматического числа в принципе можно обобщить по-разному.',
#   (404.66, 408.15)],
#  ['Silence', '', (408.15, 408.95)],
#  ['Lector',
#   ' Можно сказать, что раскраска правильная, если... Раскраска вершин, конечно, опять вершины красятся правильным образом. Если, например, все вообще вершины каждого ребра разного цвета.',
#   (408.95, 419.91)],
#  ['Silence', '', (419.91, 420.78)],
#  ['Lector',
#   ' Ну, это будет естественным обобщением того, как мы понимали хроматическое число графа. Концы каждого ребра имеют разные цвета. Но тут концов больше у каждого ребра. Можно сказать, что вот каждый конец, там все вот эти концы имеют разные цвета. На самом деле это такое, ну, не совсем правильное в каком-то смысле обобщение.',
#   (420.78, 441.6)],
#  ['Silence', '', (441.6, 442.26)],
#  ['Lector',
#   ' Более правильное обобщение звучит в каком-то смысле проще.',
#   (442.26, 445.35)],
#  ['Silence', '', (445.35, 446.19)],
#  ['Lector', ' хроматическое число', (446.19, 447.64)],
#  ['Silence', '', (447.64, 451.42)],
#  ['Lector', ' гиперграфа', (451.42, 452.48)],
#  ['Silence', '', (452.48, 453.04)],
#  ['Lector', ' Это минимальное число.', (453.04, 454.73)],
#  ['Silence', '', (454.73, 458.63)],
#  ['Lector', ' цветов.', (458.63, 459.25)],
#  ['Silence', '', (459.25, 462.91)],
#  ['Lector', ' Такой.', (462.91, 463.52)],
#  ['Silence', '', (463.52, 467.32)],
#  ['Lector', ' раскраски.', (467.32, 468.31)],
#  ['Silence', '', (468.31, 470.91)],
#  ['Lector', ' множество вершин', (470.91, 472.13)],
#  ['Silence', '', (472.13, 474.54)],
#  ['Lector', ' то каждое ребро просто неодноцветно.', (474.54, 477.12)],
#  ['Silence', '', (477.12, 488.88)],
#  ['Lector',
#   ' То есть мы не требуем, чтобы все вершины данного ребра имели разные цвета. Мы хотим только, чтобы там присутствовало хотя бы два цвета среди цветов вершин.',
#   (488.88, 497.3)],
#  ['Silence', '', (497.3, 498.6)],
#  ['Lector',
#   ' Каждое ребро должно быть неодноцветным. Тогда мы говорим, что все хорошо. Наименьшее количество цветов в такой раскраске называется карматическим числом.',
#   (498.6, 506.35)],
#  ['Silence', '', (506.35, 506.74)],
#  ['Lector', ' гипер графа', (506.74, 507.61)],
#  ['Silence', '', (507.61, 508.37)],
#  ['Lector',
#   ' Такое на самом деле в каком-то смысле более естественное обобщение.',
#   (508.37, 511.95)],
#  ['Silence', '', (511.95, 514.67)],
#  ['Lector', ' Так.', (514.67, 515.19)],
#  ['Silence', '', (515.19, 516.27)],
#  ['Lector',
#   ' Ну, давайте, наверное, я докажу сразу очень простую теорему.',
#   (516.27, 521.43)],
#  ['Silence', '', (521.43, 524.05)],
#  ['Lector', ' которую придумал', (524.05, 525.67)],
#  ['Silence', '', (525.67, 526.51)],
#  ['Lector', ' Придумали даже, вернее, Эрдош.', (526.51, 528.69)],
#  ['Silence', '', (528.69, 529.97)],
#  ['Lector', ' не хайнал', (529.97, 531.24)],
#  ['Silence', '', (531.24, 531.81)],
#  ['Lector',
#   ' Ну, как придумали? Пронаблюдали. Простое совершенно утверждение, понятное, ничего тут такого открытия сейчас не будет. Эрда Шихайнелл, пронаблюдали ее в 1961 году, но она послужила затравкой для очень большой науки и, в частности, для очень существенных применений вероятностного метода в комбинаторных задачах.',
#   (531.81, 551.44)],
#  ['Silence', '', (551.44, 552.27)],
#  ['Lector', ' Значит, теорема звучит так.', (552.27, 553.73)],
#  ['Silence', '', (553.73, 554.73)],
#  ['Lector', ' Пусть.', (554.73, 555.29)],
#  ['Silence', '', (555.29, 557.14)],
#  ['Lector', ' Аш.', (557.14, 557.63)],
#  ['Silence', '', (557.63, 560.38)],
#  ['Lector', ' N – однородный гиперграф.', (560.38, 561.95)],
#  ['Silence', '', (561.95, 568.95)],
#  ['Lector', ' Пусть также...', (568.95, 570.07)],
#  ['Silence', '', (570.07, 572.25)],
#  ['Lector', ' Количество его ребер', (572.25, 573.54)],
#  ['Silence', '', (573.54, 574.29)],
#  ['Lector', ' Ну, давайте строго меньше.', (574.29, 575.7)],
#  ['Silence', '', (575.7, 576.5)],
#  ['Lector', ' чем 2 в n минус первой степени,', (576.5, 578.34)],
#  ['Silence', '', (578.34, 579.16)],
#  ['Lector',
#   ' n и n одно и то же, здесь и здесь, то есть она однородный гиперграф, а количество ребер в терминах вот этого n, количество вершин в каждом ребре, не слишком большое.',
#   (579.16, 587.79)],
#  ['Silence', '', (587.79, 588.24)],
#  ['Lector', ' Меньше чем.', (588.24, 588.97)],
#  ['Silence', '', (588.97, 590.35)],
#  ['Lector', ' 2 в n минус первой степени.', (590.35, 591.8)],
#  ['Silence', '', (591.8, 593.12)],
#  ['Lector', ' Тогда...', (593.12, 593.68)],
#  ['Silence', '', (593.68, 596.95)],
#  ['Lector', ' Хиаташ.', (596.95, 597.74)],
#  ['Silence', '', (597.74, 600.07)],
#  ['Lector', ' Не больше двойки.', (600.07, 601.17)],
#  ['Silence', '', (601.17, 604.53)],
#  ['Lector',
#   ' Ну, на самом деле, можно сказать, равняется двойке, потому что если есть хотя бы одно ребро, то, конечно, одного цвета уже не хватит.',
#   (604.53, 611.73)],
#  ['Silence', '', (611.73, 612.86)],
#  ['Lector', ' Если гиперграф не пустой,', (612.86, 614.72)],
#  ['Silence', '', (614.72, 615.92)],
#  ['Lector',
#   ' Но формально, наверное, это правильнее, потому что вдруг он пустой, вот вдруг такое несчастье случилось. Наверное, присутствующие в этой как живой, так и виртуальной аудитории еще знают такое выражение, как «двудольный граф».',
#   (615.92, 632.34)],
#  ['Silence', '', (632.34, 633.94)],
#  ['Lector',
#   ' Но вот это естественное обобщение, что такое двудольный граф. Это граф, у которого хроматическое число 2.',
#   (633.94, 640.79)],
#  ['Silence', '', (640.79, 641.6)],
#  ['Lector',
#   ' Если у гиперграфа хроматическое число 2, то тоже, естественно, его называют двудольно.',
#   (641.6, 646.58)],
#  ['Silence', '', (646.58, 647.51)],
#  ['Lector',
#   ' Есть две доли вершин, покрашенные в свои цвета, и все ребра так вот перекрестно накрываются этими вершинами. А внутри этого множества вершин одного цвета никаких ребер нету.',
#   (647.51, 658.44)],
#  ['Silence', '', (658.44, 660.21)],
#  ['Lector',
#   ' То есть, если ребер у гиперграфа относительно мало,',
#   (660.21, 664.52)],
#  ['Silence', '', (664.52, 665.83)],
#  ['Lector', ' То он двудолин.', (665.83, 666.71)],
#  ['Silence', '', (666.71, 667.61)],
#  ['Lector',
#   ' Но доказательства можно, конечно, провести, не прибегая к помощи какой-либо вероятности, потому что здесь вероятность элементарная.',
#   (667.61, 677.92)],
#  ['Silence', '', (677.92, 678.74)],
#  ['Lector',
#   ' Ну, то есть можно сравнивать просто количество раскрасок.',
#   (678.74, 681.71)],
#  ['Silence', '', (681.71, 682.74)],
#  ['Lector',
#   ' И это будет то же самое абсолютно. Если вы такие умные, продвинутые, уже заранее понимаете такие вещи, это здорово. Но я вот вас все равно предвосхищаю, так сказать, ваше замечание предвосхищаю. И говорю, что да, конечно, в данном случае в доказательстве вероятность будет не очень по существу. Но это затравка для будущего продвинутого вероятностного метода.',
#   (682.74, 704.41)],
#  ['Silence', '', (704.41, 705.25)],
#  ['Lector', ' Значит...', (705.25, 706.25)],
#  ['Silence', '', (706.25, 706.62)],
#  ['Lector', ' Смотрите.', (706.62, 707.26)],
#  ['Silence', '', (707.26, 708.81)],
#  ['Lector',
#   ' Давайте я все-таки буду рассуждать в терминах вероятности, что опять же я предполагаю, что слушатели, которые пришли в магистратуру, базовый курс вероятности знают.',
#   (708.81, 717.71)],
#  ['Silence', '', (717.71, 718.38)],
#  ['Lector',
#   ' Ну, например, товарищи, тем не менее, я вас спрошу. Вот вы знаете, что такое схема испытаний Бернули?',
#   (718.38, 724.98)],
#  ['Silence', '', (724.98, 725.99)],
#  ['Lector', ' С монетку когда бросают, да?', (725.99, 727.8)],
#  ['Silence', '', (727.8, 728.9)],
#  ['Lector', ' В Zoom тоже хорошо бы как-то отреагировать.', (728.9, 731.29)],
#  ['Silence', '', (731.29, 732.34)],
#  ['Lector', ' Ой.', (732.34, 732.74)],
#  ['Silence', '', (732.74, 736.56)],
#  ['Lector',
#   ' По-моему, народ не то, чтобы полег, а просто отвлекся.',
#   (736.56, 738.94)],
#  ['Silence', '', (738.94, 740.84)],
#  ['Audience', ' Да, знаем.', (740.84, 741.64)],
#  ['Silence', '', (741.64, 741.7)],
#  ['Lector', ' А?', (741.7, 742.04)],
#  ['Silence', '', (742.04, 742.7)],
#  ['Lector', ' Знаете, например...', (742.7, 743.73)],
#  ['Audience', ' Да, знаю.', (743.02, 743.64)],
#  ['Silence', '', (743.64, 743.95)],
#  ['Lector',
#   ' монетку бросать там схемы испытаний бернули возникает пока никаких продвинутых вопросов тут нету давайте просто возьмем вот зафиксируем этот гипер граф и будем красить вершины и',
#   (743.95, 755.76)],
#  ['Silence', '', (755.76, 756.59)],
#  ['Lector',
#   ' независимо друг от друга, то есть взаимно независимо, независимо в совокупности каждую, с вероятностью 1,2 условно в красный цвет и с вероятностью 1,2 в синий.',
#   (756.59, 766.59)],
#  ['Silence', '', (766.59, 767.39)],
#  ['Lector',
#   ' красим вершины одну за другой или одновременно просто взаимно независимо и',
#   (767.39, 773.28)],
#  ['Silence', '', (773.28, 774.51)],
#  ['Lector', ' Красный и синий цвета.', (774.51, 777.11)],
#  ['Silence', '', (777.11, 778.59)],
#  ['Lector', ' С вероятностью одна-вторая.', (778.59, 780.26)],
#  ['Silence', '', (780.26, 782.58)],
#  ['Lector',
#   ' Ну, фактически я просто мог сказать, давайте рассмотрим случайную раскраску, то есть каждая раскраска имеет вероятность единицы поделить на 2 в степени.',
#   (782.58, 791.91)],
#  ['Silence', '', (791.91, 792.57)],
#  ['Lector', ' Мощность множества вершин.', (792.57, 794.03)],
#  ['Silence', '', (794.03, 794.4)],
#  ['Lector',
#   ' Но мне не хочется так глинно говорить, потому что я даже не знаю, сколько вершин. Заметьте, в этом утверждении количество вершин не играет никакой роли.',
#   (794.4, 802.37)],
#  ['Silence', '', (802.37, 803.75)],
#  ['Lector',
#   ' Играет роль только количество вершин в каждом ребре.',
#   (803.75, 806.76)],
#  ['Silence', '', (806.76, 807.35)],
#  ['Lector',
#   ' Но количество всех вершин не играет роли никакой. Поэтому мне удобнее говорить вот именно в терминах бросания монетки. Красим вершины в красные и синие цвета, с вероятностью одна вторая.',
#   (807.35, 817.54)],
#  ['Silence', '', (817.54, 819.28)],
#  ['Lector',
#   ' Так, ну, вам, конечно, стоит вспоминать немножко вероятности, понимать, что, по сути, все события теперь это просто множество раскрасок, правильно?',
#   (819.28, 827.85)],
#  ['Silence', '', (827.85, 829.22)],
#  ['Lector', ' что элементарный исход – это раскраска.', (829.22, 831.09)],
#  ['Silence', '', (831.09, 832.34)],
#  ['Lector',
#   ' Ну так, чтобы вам просто было легче ориентироваться, а так-то ничего особо умного нет.',
#   (832.34, 837.18)],
#  ['Silence', '', (837.18, 837.64)],
#  ['Lector',
#   ' Вот смотрите, если у нас есть какое-то ребро,',
#   (837.64, 840.03)],
#  ['Silence', '', (840.03, 841.81)],
#  ['Lector',
#   ' Но давайте поставим ему в соответствие событие, состоящее в том, что Е...',
#   (841.81, 847.14)],
#  ['Silence', '', (847.14, 847.65)],
#  ['Lector', ' Одноцветно, вот в такой случайной раскраске.', (847.65, 850.24)],
#  ['Silence', '', (850.24, 851.63)],
#  ['Lector',
#   ' А с индексом Е это событие, состоящее в том, что в случайной раскраске ребро одноцветное.',
#   (851.63, 856.94)],
#  ['Silence', '', (856.94, 858.34)],
#  ['Lector', ' О!', (858.34, 858.87)],
#  ['Silence', '', (858.87, 859.2)],
#  ['Lector',
#   ' Грандиозный вопрос, какова вероятность этого события.',
#   (859.2, 862.51)],
#  ['Silence', '', (862.51, 863.58)],
#  ['Lector',
#   ' Вот опять, здесь очень удобная интерпретация с монеткой, потому что нам не нужно знать, сколько вершин, для того, чтобы сразу сказать, какова вероятность этого события.',
#   (863.58, 872.54)],
#  ['Silence', '', (872.54, 877.24)],
#  ['Lector', ' Ну да, да.', (877.24, 878.58)],
#  ['Silence', '', (878.58, 879.03)],
#  ['Lector', ' 2 умножить...', (879.03, 880.3)],
#  ['Silence', '', (880.3, 880.75)],
#  ['Lector', ' На 1, 2 в n-ной степени.', (880.75, 882.75)],
#  ['Silence', '', (882.75, 883.89)],
#  ['Lector',
#   ' 2, потому что оно все может быть красным, оно все может быть синим, вот два варианта. Ну и для каждого из вариантов вероятность 1, 2, V. Все N вершин данного ребра покрасились в один и тот же цвет. Ну, это можно вот так переписать, после чего, по-моему, все становится понятно. Но я все-таки напишу с большим пафосом то, что получилось. Вот у нас есть объединение по всем E.',
#   (883.89, 907.64)],
#  ['Silence', '', (907.64, 908.58)],
#  ['Lector', ' изъя', (908.58, 909.31)],
#  ['Silence', '', (909.31, 909.76)],
#  ['Lector',
#   ' событий АЕ. Что из себя представляет вот это событие, состоящее в объединении?',
#   (909.76, 915.03)],
#  ['Silence', '', (915.03, 919.84)],
#  ['Lector', ' Нет.', (919.84, 920.26)],
#  ['Silence', '', (920.26, 920.83)],
#  ['Lector', ' Это то, что хотя бы одно, одноцветно.', (920.83, 923.09)],
#  ['Silence', '', (923.09, 925.22)],
#  ['Lector',
#   ' А Е – это что вот это конкретное ребро одноцветное.',
#   (925.22, 929.61)],
#  ['Silence', '', (929.61, 930.03)],
#  ['Lector',
#   ' А объединение АЕ – это что хотя бы одно ребро целиком одноцветно. То есть это плохое событие для нас.',
#   (930.03, 938.06)],
#  ['Silence', '', (938.06, 938.53)],
#  ['Lector',
#   ' Нам хочется, чтобы все ребра были не одноцветные. А это плохое событие, что существует одноцветное ребро.',
#   (938.53, 945.28)],
#  ['Silence', '', (945.28, 947.14)],
#  ['Lector', ' Это множество раскрасок,', (947.14, 948.76)],
#  ['Silence', '', (948.76, 949.22)],
#  ['Lector', ' в которых хотя бы одно ребро на цвет.', (949.22, 951.51)],
#  ['Silence', '', (951.51, 952.69)],
#  ['Lector', ' Естественно, это не больше, чем сумма.', (952.69, 955.14)],
#  ['Silence', '', (955.14, 955.95)],
#  ['Lector', ' По here is here.', (955.95, 957.82)],
#  ['Silence', '', (957.82, 958.58)],
#  ['Lector', ' вероятности айе', (958.58, 960.24)],
#  ['Silence', '', (960.24, 960.91)],
#  ['Lector', ' А это в точности равно...', (960.91, 962.77)],
#  ['Silence', '', (962.77, 963.85)],
#  ['Lector', ' 2 в степени 1 минус n.', (963.85, 965.92)],
#  ['Silence', '', (965.92, 966.63)],
#  ['Lector', ' на мощность Е.', (966.63, 968.0)],
#  ['Silence', '', (968.0, 968.66)],
#  ['Lector',
#   ' Но мощность Е по условию меньше, чем 2 в степени n-1, строго.',
#   (968.66, 973.53)],
#  ['Silence', '', (973.53, 974.51)],
#  ['Lector', ' Поэтому мы получаем', (974.51, 975.9)],
#  ['Silence', '', (975.9, 977.14)],
#  ['Lector', ' единичку.', (977.14, 977.84)],
#  ['Silence', '', (977.84, 979.46)],
#  ['Lector',
#   ' Нет, ну, конечно, любая вероятность не превосходит единицы, тут ничего умного нет, но здесь-то строго меньше.',
#   (979.46, 987.27)],
#  ['Silence', '', (987.27, 987.74)],
#  ['Lector',
#   ' И это плохое событие. Существует одноцветное ребро.',
#   (987.74, 991.66)],
#  ['Silence', '', (991.66, 992.13)],
#  ['Lector',
#   ' Значит, отрицание этого плохого события действительно такое, как нам нужно, все ребра не одноцветны.',
#   (992.13, 998.36)],
#  ['Silence', '', (998.36, 998.68)],
#  ['Lector', ' И его вероятность строго положительна.', (998.68, 1001.33)],
#  ['Silence', '', (1001.33, 1002.64)],
#  ['Lector', ' Ну давайте, я напишу, ладно.', (1002.64, 1004.28)],
#  ['Silence', '', (1004.28, 1004.65)],
#  ['Lector', ' Вероятность пересечения отрицаний...', (1004.65, 1007.25)],
#  ['Silence', '', (1007.25, 1009.39)],
#  ['Lector', ' Стало быть, строго больше нуля.', (1009.39, 1011.08)],
#  ['Silence', '', (1011.08, 1012.58)],
#  ['Lector',
#   ' Но вы не забывайте, это пересечение отрицания – это просто множество раскрасок.',
#   (1012.58, 1016.01)],
#  ['Silence', '', (1016.01, 1016.85)],
#  ['Lector',
#   ' Ну, то есть это множество, очевидно, не пусто, если вероятнее.',
#   (1016.85, 1019.03)],
#  ['Audience', ' больше нуля.', (1019.03, 1020.04)],
#  ['Silence', '', (1020.04, 1021.34)],
#  ['Audience', ' Все.', (1021.34, 1021.73)],
#  ['Silence', '', (1021.73, 1027.3)],
#  ['Lector',
#   ' Все это можно было, как я уже говорил, произнести на количественном языке.',
#   (1027.3, 1032.26)],
#  ['Silence', '', (1032.26, 1032.76)],
#  ['Lector',
#   ' Ну просто сказать, есть 2 в степени мощность V раскрасок.',
#   (1032.76, 1036.71)],
#  ['Silence', '', (1036.71, 1037.56)],
#  ['Lector',
#   ' Среди них есть такие, которые оставляют одноцветным первое ребро, такие, которые оставляют одноцветным второе. Вот мы их объединим.',
#   (1037.56, 1046.03)],
#  ['Silence', '', (1046.03, 1047.09)],
#  ['Lector',
#   ' Мощность этого множества будет меньше, чем 2 в степени В.',
#   (1047.09, 1050.62)],
#  ['Silence', '', (1050.62, 1051.26)],
#  ['Lector',
#   ' Ну вот, значит, есть такие раскраски, которые действительно, вот, какие нам нужны. Но так гораздо удобнее. И главное, что потом начнутся какие-то более продвинутые вероятностные технологии, повязанные, скажем, на независимость событий, повязанные на неравенство концентрации меры. Ну, может, вы таких страшных слов не слышали, но неравенство Чебышева.',
#   (1051.26, 1073.69)],
#  ['Silence', '', (1073.69, 1074.02)],
#  ['Lector', ' Вы же слышали?', (1074.02, 1074.9)],
#  ['Silence', '', (1074.9, 1075.66)],
#  ['Lector',
#   ' А это неравенство плотной концентрации мира. Но я про это потом расскажу очень подробно. Есть более тонкие неравенства. Это важно. Это используется не только в комбинаторике. Это нужно для вероятности, для самой. Это нужно для оптимизации, например.',
#   (1075.66, 1089.46)],
#  ['Silence', '', (1089.46, 1090.22)],
#  ['Lector',
#   ' Вот, ну все, теорему так или иначе я доказал.',
#   (1090.22, 1093.11)],
#  ['Silence', '', (1093.11, 1093.75)],
#  ['Lector',
#   ' И она мотивирует появление некоторой экстремальной характеристики на множестве гиперграфов, которая обозначается вот так –',
#   (1093.75, 1101.19)],
#  ['Silence', '', (1101.19, 1103.5)],
#  ['Lector',
#   ' Собственно, это обозначение Эрда Шайнелл и придумали в 1961 году.',
#   (1103.5, 1107.57)],
#  ['Silence', '', (1107.57, 1108.75)],
#  ['Lector',
#   ' Они, правда, почему-то употребляли термин «свойство Б гиперграфа»,',
#   (1108.75, 1112.75)],
#  ['Silence', '', (1112.75, 1112.94)],
#  ['Lector',
#   ' Вместо того, чтобы говорить о хроматическом числе. Ну, как-то так вот тогда сложилось. Но неважно. Даже не буду говорить, что такое свойство B не имеет значения.',
#   (1112.94, 1120.95)],
#  ['Silence', '', (1120.95, 1121.44)],
#  ['Lector', ' М-10.', (1121.44, 1122.24)],
#  ['Silence', '', (1122.24, 1123.43)],
#  ['Lector', ' Это минимальная...', (1123.43, 1125.07)],
#  ['Silence', '', (1125.07, 1126.91)],
#  ['Lector', ' Натуральная М', (1126.91, 1128.16)],
#  ['Silence', '', (1128.16, 1130.12)],
#  ['Lector', ' Такое, что существует.', (1130.12, 1132.07)],
#  ['Silence', '', (1132.07, 1135.75)],
#  ['Lector', ' Н. Однородный.', (1135.75, 1136.98)],
#  ['Silence', '', (1136.98, 1138.77)],
#  ['Lector', ' гипсокардиолога.', (1138.77, 1139.03)],
#  ['Audience', ' торгов.', (1139.03, 1139.18)],
#  ['Lector', ' раз', (1139.18, 1139.35)],
#  ['Silence', '', (1139.35, 1139.41)],
#  ['Silence', '', (1139.41, 1139.53)],
#  ['Silence', '', (1139.53, 1147.65)],
#  ['Lector', ' у которого М-рёбер,', (1147.65, 1149.18)],
#  ['Silence', '', (1149.18, 1152.32)],
#  ['Lector', ' А хроматическое число больше двойки.', (1152.32, 1154.2)],
#  ['Silence', '', (1154.2, 1156.49)],
#  ['Lector', ' Вот так.', (1156.49, 1157.1)],
#  ['Silence', '', (1157.1, 1161.37)],
#  ['Lector',
#   ' Ну, давайте, это надо осознать. Мы чего поняли? Если у гиперграфа ребер меньше, чем 2 в n-1 степени, то это не так.',
#   (1161.37, 1169.13)],
#  ['Silence', '', (1169.13, 1169.52)],
#  ['Lector', ' У него хроматическое число не больше 2.', (1169.52, 1171.39)],
#  ['Silence', '', (1171.39, 1173.0)],
#  ['Lector',
#   ' Ну, то есть это означает, что здесь мы пытаемся найти минимальное m, при котором существует контрпример к теореме, только что доказанной.',
#   (1173.0, 1181.35)],
#  ['Silence', '', (1181.35, 1182.39)],
#  ['Lector',
#   ' Очевидно, оно больше, чем 2Vn-1, больше либо равно.',
#   (1182.39, 1185.55)],
#  ['Silence', '', (1185.55, 1186.06)],
#  ['Lector',
#   ' То есть теорема, которую мы доказали, влечет в утверждение о том, что m от n больше либо равно...',
#   (1186.06, 1192.89)],
#  ['Silence', '', (1192.89, 1194.73)],
#  ['Lector', ' 2 в n минус первой степени.', (1194.73, 1196.35)],
#  ['Silence', '', (1196.35, 1197.01)],
#  ['Lector',
#   ' Ну, еще раз, потому что если у гиперграфа меньше, чем столько ребер, то он красится в два цвета. А нам нужно такое количество ребер, при которых найдется гиперграф, который невозможно покрасить в два цвета.',
#   (1197.01, 1209.02)],
#  ['Audience', ' Субтитры создавал DimaTorzok', (1209.02, 1209.41)],
#  ['Silence', '', (1209.41, 1211.28)],
#  ['Audience', ' Понятно говорю, да?', (1211.28, 1212.21)],
#  ['Silence', '', (1212.21, 1214.64)],
#  ['Audience', ' Но в Зуме народ тихий,', (1214.64, 1215.98)],
#  ['Lector', ' СМЕХ', (1215.98, 1216.48)],
#  ['Silence', '', (1216.48, 1218.03)],
#  ['Lector', ' Ну, наверное, понятно.', (1218.03, 1219.25)],
#  ['Silence', '', (1219.25, 1220.11)],
#  ['Audience', ' Ну да.', (1220.11, 1220.62)],
#  ['Silence', '', (1220.62, 1221.46)],
#  ['Lector', ' Ну, хорошо.', (1221.46, 1222.64)],
#  ['Silence', '', (1222.64, 1223.22)],
#  ['Lector',
#   ' Но давайте подумаем, без всякой даже вероятности, может быть вообще все глупость какая-то, мы некорректную задачу поставили.',
#   (1223.22, 1230.78)],
#  ['Silence', '', (1230.78, 1231.47)],
#  ['Lector', ' Вообще можно как-то МАТН сверху оценить?', (1231.47, 1233.66)],
#  ['Silence', '', (1233.66, 1238.2)],
#  ['Lector', ' Ну, задача может оказаться глупой.', (1238.2, 1239.99)],
#  ['Silence', '', (1239.99, 1241.68)],
#  ['Lector',
#   ' Вдруг не существует контрпримера ни с каким количеством ребер, а вообще на самом деле просто любой эноднородный гиперграф красится.',
#   (1241.68, 1248.81)],
#  ['Silence', '', (1248.81, 1253.0)],
#  ['Lector',
#   ' Во-во-во, у меня в аудитории уже появилась очень правильная мысль. Я говорю, что это обычно придумывается самостоятельно. Полный такт.',
#   (1253.0, 1259.5)],
#  ['Silence', '', (1259.5, 1260.07)],
#  ['Lector', ' Какой-нибудь какой.', (1260.07, 1261.32)],
#  ['Silence', '', (1261.32, 1261.88)],
#  ['Lector', ' Ну, надо поменьше, конечно, получше.', (1261.88, 1263.73)],
#  ['Silence', '', (1263.73, 1264.44)],
#  ['Lector', ' Оценку получить.', (1264.44, 1265.39)],
#  ['Silence', '', (1265.39, 1268.61)],
#  ['Lector', ' Полная, это очень хорошая идея.', (1268.61, 1269.94)],
#  ['Silence', '', (1269.94, 1274.79)],
#  ['Lector', ' Ну, даже 2n-1.', (1274.79, 1276.52)],
#  ['Silence', '', (1276.52, 1276.66)],
#  ['Lector',
#   ' Правильно, 2n, конечно, хватит, но даже 2n-1 хватит. Значит, что мы тут обсудили с единственным слушателем, который расположен в 115-й КПМ?',
#   (1276.66, 1286.75)],
#  ['Silence', '', (1286.75, 1287.95)],
#  ['Lector',
#   ' Не, ну может у меня два слушателя, конечно, один из них оператор. Но это уж я не знаю. Давайте рассмотрим гиперграф, у которого вот такие вершины.',
#   (1287.95, 1296.79)],
#  ['Silence', '', (1296.79, 1298.97)],
#  ['Lector',
#   ' Так, ну, товарищи, я думаю, что понятно, вершины можно просто всегда считать числами, это неважно. Просто как-то их там перенумеровали, и все, люди это там или еще что, это уже другой вопрос. Числа от единицы до 2n-1, и мы вот на этом множестве вершин, это v,',
#   (1298.97, 1314.76)],
#  ['Silence', '', (1314.76, 1316.38)],
#  ['Lector', ' Берем все возможные ребра.', (1316.38, 1318.56)],
#  ['Silence', '', (1318.56, 1319.03)],
#  ['Lector', ' То есть,', (1319.03, 1319.96)],
#  ['Silence', '', (1319.96, 1320.53)],
#  ['Lector', ' Можно вот так обозначить это, c из v по n.', (1320.53, 1323.4)],
#  ['Silence', '', (1323.4, 1323.45)],
#  ['Lector',
#   ' Это тоже для комбинаторики, кстати, стандартное обозначение, когда c берут из множества, а не из его мощности. То есть это не число, а множество всех n элементных подмножеств вот этого множества.',
#   (1323.45, 1335.35)],
#  ['Silence', '', (1335.35, 1336.04)],
#  ['Lector', ' Это стандартное обозначение.', (1336.04, 1337.78)],
#  ['Silence', '', (1337.78, 1338.1)],
#  ['Lector',
#   ' С из множества почему-то это все возможные подмножества. Мощность его, конечно, такая, С из мощности Vπn. Берем такой полный n-однородный гиперграф, на этом множество вершин. Но смотрите, как бы мы не покрасили множество вершин в два цвета, в какой-то цвет из этих двух будут покрашены не менее, чем n вершин.',
#   (1338.1, 1358.4)],
#  ['Silence', '', (1358.4, 1358.86)],
#  ['Lector', ' очевидного принципа Дерихлея.', (1358.86, 1360.68)],
#  ['Silence', '', (1360.68, 1364.19)],
#  ['Lector',
#   ' Поскольку каждое множество мощностей N сейчас является ребром,',
#   (1364.19, 1368.12)],
#  ['Silence', '', (1368.12, 1368.64)],
#  ['Lector', ' Ну вот это уже противоречие.', (1368.64, 1370.42)],
#  ['Silence', '', (1370.42, 1370.85)],
#  ['Lector',
#   ' Покрасили в два цвета и тотчас же нашли какое-то одноцветное ребро. При любой раскраске. То есть как ни старайся, как ни крась, но вот какое-то ребро будет целиком, к сожалению, одного цвета. И это означает, что МАТН не превосходит СС2Н-1ОН.',
#   (1370.85, 1387.92)],
#  ['Silence', '', (1387.92, 1394.94)],
#  ['Silence', '', (1394.94, 1394.95)],
#  ['Lector',
#   ' Ну, товарищи, если вы у меня прям продвинутые-продвинутые, то вы даже, наверное, знаете, как растет вот эта величина.',
#   (1394.95, 1402.61)],
#  ['Silence', '', (1402.61, 1406.53)],
#  ['Lector',
#   ' Не, ну я чуть-чуть иронизирую, потому что на самом деле это не то, что великое знание.',
#   (1406.53, 1410.24)],
#  ['Silence', '', (1410.24, 1411.34)],
#  ['Lector', ' Так?', (1411.34, 1411.62)],
#  ['Silence', '', (1411.62, 1412.67)],
#  ['Lector', ' Нет, n в степени n это чересчур.', (1412.67, 1414.65)],
#  ['Silence', '', (1414.65, 1416.11)],
#  ['Lector', ' Это превосходит всяческие ожидания.', (1416.11, 1419.15)],
#  ['Silence', '', (1419.15, 1419.44)],
#  ['Lector',
#   ' Потому что, очевидно, следующее, понял, в этом месте уже не понимаете, но ничего страшного.',
#   (1419.44, 1425.02)],
#  ['Silence', '', (1425.02, 1426.17)],
#  ['Lector', ' Вот так вот напишем.', (1426.17, 1427.54)],
#  ['Silence', '', (1427.54, 1427.71)],
#  ['Lector', ' Субтитры сделал DimaTorzok', (1427.71, 1428.2)],
#  ['Silence', '', (1428.2, 1434.44)],
#  ['Lector',
#   ' Ну, сумма всех цешек с фиксированным нижним индексом это что?',
#   (1434.44, 1438.02)],
#  ['Silence', '', (1438.02, 1441.85)],
#  ['Audience', ' Да, в степени.', (1441.85, 1442.73)],
#  ['Silence', '', (1442.73, 1443.99)],
#  ['Lector', ' Ну, не она, наверное, была.', (1443.99, 1445.21)],
#  ['Audience', ' Или на минус один.', (1444.63, 1445.86)],
#  ['Silence', '', (1445.86, 1446.79)],
#  ['Silence', '', (1446.79, 1446.83)],
#  ['Silence', '', (1446.83, 1446.88)],
#  ['Audience', ' Нет.', (1446.88, 1447.23)],
#  ['Silence', '', (1447.13, 1447.21)],
#  ['Silence', '', (1447.21, 1447.23)],
#  ['Silence', '', (1447.23, 1447.25)],
#  ['Audience', ' Да.', (1447.25, 1447.38)],
#  ['Silence', '', (1447.38, 1449.42)],
#  ['Lector',
#   ' 2 в степени 2n минус 1, ну примерно 4 в n, в точности, деление на двойку.',
#   (1449.42, 1454.03)],
#  ['Silence', '', (1454.03, 1455.26)],
#  ['Lector',
#   ' Но я специально в серединке написал нашу «ц»',
#   (1455.26, 1458.49)],
#  ['Silence', '', (1458.49, 1459.85)],
#  ['Lector',
#   ' Ну, во-первых, потому что она действительно в серединке, то есть она самая большая.',
#   (1459.85, 1463.06)],
#  ['Silence', '', (1463.06, 1463.85)],
#  ['Lector',
#   ' Вы знаете, что они возрастают сначала, потом убывают.',
#   (1463.85, 1466.37)],
#  ['Silence', '', (1466.37, 1466.86)],
#  ['Lector',
#   ' Любовероятность, знаете, вы знаете вот такой горбик, называется нормальное распределение. А он откуда берется? Он ровно отсюда берется.',
#   (1466.86, 1474.3)],
#  ['Silence', '', (1474.3, 1475.33)],
#  ['Lector',
#   ' Тэшки сначала вот так растут, растут, а потом так же симметрично убывают. Ну ладно, это какие-то страшные слова, нормальное распределение. Но это школьнику можно объяснить, который комбинаторику знает. Понятно, что сумма положительных слагаемых, в серединке стоит какое-то из них, но ясно, что оно меньше, чем вот эта величина.',
#   (1475.33, 1493.81)],
#  ['Silence', '', (1493.81, 1495.95)],
#  ['Lector', ' Это точно.', (1495.95, 1497.15)],
#  ['Silence', '', (1497.15, 1497.6)],
#  ['Lector',
#   ' Там, тупо меньше, чем 4 в степени n. Ну, или 4 в степени n пополам.',
#   (1497.6, 1502.02)],
#  ['Silence', '', (1502.02, 1503.49)],
#  ['Lector',
#   ' Другое дело, что поскольку это самое большое слагаемое,',
#   (1503.49, 1506.9)],
#  ['Silence', '', (1506.9, 1507.95)],
#  ['Lector', ' то оно же', (1507.95, 1509.18)],
#  ['Silence', '', (1509.18, 1509.7)],
#  ['Lector', ' СМЕХ', (1509.7, 1510.24)],
#  ['Silence', '', (1510.24, 1511.54)],
#  ['Lector', ' Конечно, и больше.', (1511.54, 1512.72)],
#  ['Silence', '', (1512.72, 1513.84)],
#  ['Lector', ' Больше оно, чем 2 в степени...', (1513.84, 1515.9)],
#  ['Silence', '', (1515.9, 1516.55)],
#  ['Lector', ' 2 минус 1 поделить на 2.', (1516.55, 1518.56)],
#  ['Silence', '', (1518.56, 1521.35)],
#  ['Lector',
#   ' где 2n – это количество слагаемых. Оно самое большое,',
#   (1521.35, 1524.94)],
#  ['Silence', '', (1524.94, 1525.55)],
#  ['Lector', ' И всего слагаемых 2n.', (1525.55, 1527.12)],
#  ['Silence', '', (1527.12, 1528.43)],
#  ['Lector',
#   ' Ну, значит, оно больше, чем вся сумма поделить на 2n.',
#   (1528.43, 1531.1)],
#  ['Silence', '', (1531.1, 1531.79)],
#  ['Lector',
#   ' Ну, вы, как люди, поступившие в магистратуру, понимаете, конечно, что экспоненты 4 в n существенно значимее,',
#   (1531.79, 1538.96)],
#  ['Silence', '', (1538.96, 1539.17)],
#  ['Lector',
#   ' для вечности, чем какая-то там линейно растущая функция. Поэтому в каком-то смысле можно считать, что',
#   (1539.17, 1546.61)],
#  ['Silence', '', (1546.61, 1547.42)],
#  ['Lector',
#   ' Верхняя оценка имеет порядок роста 4 вольт. Но в каком-то смысле.',
#   (1547.42, 1551.21)],
#  ['Silence', '', (1551.21, 1552.09)],
#  ['Lector',
#   ' А нижняя оценка 2 в N, то есть за сорт-то большой.',
#   (1552.09, 1555.26)],
#  ['Silence', '', (1555.26, 1557.31)],
#  ['Lector',
#   ' Но возникает вопрос, нельзя ли его устранить. И вот вопрос об устранении этого зазора решается в том числе с помощью методов, которые развивают вот этот вот простейший вероятностный подход. То есть с одной стороны мы сможем сейчас продвинуться в этой задаче, а с другой стороны мы потихоньку начнем двигаться в сторону чуть более продвинутых методов, нежели просто вероятность объединения не больше, чем сумма.',
#   (1557.31, 1580.44)],
#  ['Silence', '', (1580.44, 1582.25)],
#  ['Lector', ' Я понятно говорю?', (1582.25, 1583.19)],
#  ['Silence', '', (1583.19, 1584.61)],
#  ['Lector',
#   ' Так, ну, я сделаю пару маленьких чисто технических замечаний.',
#   (1584.61, 1589.15)],
#  ['Silence', '', (1589.15, 1589.42)],
#  ['Lector', ' на самом деле', (1589.42, 1590.75)],
#  ['Silence', '', (1590.75, 1591.6)],
#  ['Lector', ' Вот дайте посмотрим на это доказательство.', (1591.6, 1593.03)],
#  ['Audience', ' Писто.', (1593.03, 1593.47)],
#  ['Silence', '', (1593.47, 1594.5)],
#  ['Audience', ' Вот здесь вот можно...', (1594.5, 1595.71)],
#  ['Silence', '', (1595.71, 1596.39)],
#  ['Audience', ' Убрать равно.', (1596.39, 1597.57)],
#  ['Silence', '', (1597.57, 1600.88)],
#  ['Audience', ' плохо.', (1600.88, 1601.27)],
#  ['Silence', '', (1601.27, 1602.03)],
#  ['Silence', '', (1602.03, 1602.06)],
#  ['Audience', ' Пачка.', (1602.06, 1602.62)],
#  ['Silence', '', (1602.62, 1602.8)],
#  ['Audience', ' Можно убрать равно.', (1602.8, 1603.88)],
#  ['Silence', '', (1603.88, 1605.97)],
#  ['Silence', '', (1605.97, 1606.01)],
#  ['Lector', ' Понимаете почему?', (1606.01, 1606.72)],
#  ['Silence', '', (1606.72, 1608.62)],
#  ['Lector',
#   ' Но потому что в этом объединении есть пересечение всех АЕ, не пустое, есть идиотская раскраска, все вершины покрасили в красный цвет.',
#   (1608.62, 1618.66)],
#  ['Silence', '', (1618.66, 1619.02)],
#  ['Lector',
#   ' она принадлежит всем вот этим событиям. Но есть и другая идиотская раскраска, все вершины покрашены в синий цвет, и она тоже принадлежит вот этим всем АЕ. То есть пересечение не пустое, но это значит, что можно такой',
#   (1619.02, 1632.67)],
#  ['Silence', '', (1632.67, 1633.68)],
#  ['Lector',
#   ' не знаю, идиотский вариант формулы включения-исключения применить, будет строго меньше.',
#   (1633.68, 1637.29)],
#  ['Silence', '', (1637.29, 1642.17)],
#  ['Lector', ' Ну, это означает, что МАТН...', (1642.17, 1645.01)],
#  ['Silence', '', (1645.01, 1645.78)],
#  ['Lector', ' Можно увеличить на единичку.', (1645.78, 1647.54)],
#  ['Silence', '', (1647.54, 1648.18)],
#  ['Lector',
#   ' В свете того, что я только что говорил, да мне плевать над военным знаменателем, это, конечно, кажется каким-то совсем изыском, но мне на самом деле не плевать над военным знаменателем совершенно.',
#   (1648.18, 1659.16)],
#  ['Silence', '', (1659.16, 1659.72)],
#  ['Lector',
#   ' И вы сейчас увидите, что поскольку МАТЭН растет ближе к этому, то там начнутся уже вопросы о том,',
#   (1659.72, 1666.0)],
#  ['Silence', '', (1666.0, 1667.38)],
#  ['Lector',
#   ' Как вот такие величины такого порядка учитываются?',
#   (1667.38, 1669.83)],
#  ['Silence', '', (1669.83, 1670.99)],
#  ['Lector',
#   ' Пока, когда зазор в экспонент, то раз, ну, говорить не о чем. Но если сейчас появятся какие-то более содержательные соображения, то мы станем вот такие вещи тоже отлавливать.',
#   (1670.99, 1680.39)],
#  ['Silence', '', (1680.39, 1681.47)],
#  ['Lector', ' Вот.', (1681.47, 1682.1)],
#  ['Silence', '', (1682.1, 1682.47)],
#  ['Lector', ' Ну все.', (1682.47, 1683.08)],
#  ['Silence', '', (1683.08, 1684.63)],
#  ['Lector', ' Ну всё?', (1684.63, 1685.44)],
#  ['Silence', '', (1685.44, 1686.82)],
#  ['Lector',
#   ' Я думаю, что за оставшееся время, у нас его не так много, ну, час у нас остался где-то, да, я попробую рассказать про улучшение верхней оценки, и здесь уже появится чуть более продвинутое вероятностное соображение, которое состоит',
#   (1686.82, 1702.01)],
#  ['Silence', '', (1702.01, 1702.82)],
#  ['Lector',
#   ' Ну, какой-то дополнительной независимости, что ли, событий.',
#   (1702.82, 1705.65)],
#  ['Silence', '', (1705.65, 1709.23)],
#  ['Audience', ' Так.', (1709.23, 1709.55)],
#  ['Silence', '', (1709.55, 1710.8)],
#  ['Audience', ' Сейчас мне нужно...', (1710.8, 1711.92)],
#  ['Silence', '', (1711.92, 1711.97)],
#  ['Silence', '', (1711.97, 1712.03)],
#  ['Silence', '', (1712.03, 1712.62)],
#  ['Audience', ' изыскать тряпку. Я ее ношу.', (1712.62, 1714.6)],
