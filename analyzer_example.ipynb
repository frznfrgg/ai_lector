# %%
import os
import warnings

import matplotlib.pyplot as plt

import rec_analyzer

warnings.filterwarnings("ignore")

# %%
PYANNOTE_AUTH_TOKEN = os.environ.get("PYANNOTE_API_KEY")
GIGACHAT_API_KEY = os.environ.get("GIGACHAT_API_KEY")
recording_path = "audio/rec.mp3"

# %%
analyzer = rec_analyzer.LectureHelper(recording_path, GIGACHAT_API_KEY, PYANNOTE_AUTH_TOKEN)

# %%
text = analyzer.lecture_text
print(text)
# Out:
#  Так, друзья, ну все, я больше подписывать пока ничего не буду, сейчас будет лекция. Значит, смотрите, ну я из года в год читаю, конечно, эти лекции, в принципе, есть их записи, но я с удовольствием прочитаю снова, может быть, что-нибудь новое случится на этот раз. На самом деле мне, конечно, хочется читать гораздо быстрее, чем обычно я это делаю, то есть начитывать такой более объемный, более мощный материал. Но традиция сложилась такая, что поскольку к магистратуру идут люди самого разного, начального уровня подготовки, приходится очень многое напоминать. Ну и, наверное, сейчас мы тоже что-то такое проделаем. Но все-таки я хочу с места в карьер пойти на какую-то достаточно продвинутую тематику. Значит, курс посвящен комбинаторике, но методы, которые хочется рассказывать в рамках этого курса, они достаточно продвинутые. То есть я ни в коем случае не хочу читать такой вводный курс о том, что такое C из НПК, там, не дай бог. Я предполагаю, что слушатели знают, что такое C из НПК. Я пр
# ...

# %%
max_speed = analyzer.max_words_speed
print(max_speed)
# Out:
# 2.5455700552884575

# %%
analyzer.time_of_top_speed
# Out:
# 212.7

# %%
analyzer.avg_words_speed
# Out:
# 1.961252317121499

# %%
x, y = analyzer.seconds, analyzer.words_per_second

plt.plot(x, y)

# %%
x, y = analyzer.seconds, analyzer.words_counter

plt.plot(x, y)

# %%
analyzer.stopwords_rate
# Out:
# 33

# %%
analyzer.labeled_chunks
# Out:
# [['Silence', 0, 9.19],
#  ['Audience', 9.19, 10.97],
#  ['Lector', 10.97, 13.06],
#  ['Silence', 13.06, 13.73],
#  ['Lector', 13.73, 56.39],
#  ['Silence', 56.39, 56.75],
#  ['Lector', 56.75, 57.74],
#  ['Silence', 57.74, 58.35],
#  ['Lector', 58.35, 87.11],
#  ['Silence', 87.11, 87.65],
#  ['Lector', 87.65, 92.24],
#  ['Silence', 92.24, 92.4],
#  ['Lector', 92.4, 102.83],
#  ['Silence', 102.83, 102.97],
#  ['Lector', 102.97, 121.24],
#  ['Silence', 121.24, 121.73],
#  ['Lector', 121.73, 153.58],
#  ['Silence', 153.58, 153.69],
#  ['Lector', 153.69, 161.52],
#  ['Silence', 161.52, 161.66],
#  ['Lector', 161.66, 162.87],
#  ['Silence', 162.87, 165.0],
#  ['Lector', 165.0, 175.19],
#  ['Silence', 175.19, 175.4],
#  ['Lector', 175.4, 176.71],
#  ['Silence', 176.71, 178.37],
#  ['Lector', 178.37, 178.45],
#  ['Silence', 178.45, 182.33],
#  ['Lector', 182.33, 188.44],
#  ['Silence', 188.44, 188.9],
#  ['Lector', 188.9, 206.51],
#  ['Silence', 206.51, 207.51],
# ...

# %%
analyzer.diagram
# Out:
# [['Lecturer', 1290.7518750000017],
#  ['Audience', 23.321249999999942],
#  ['Silence', 418.75034374999836]]

# %%
analyzer.top_words
# Out:
# [(109, 'в'),
#  (74, 'что'),
#  (73, 'это'),
#  (71, 'ну'),
#  (56, 'не'),
#  (53, 'вот'),
#  (50, 'и'),
#  (46, 'есть'),
#  (43, 'то'),
#  (40, 'но')]
